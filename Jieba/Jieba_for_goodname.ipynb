# %%
import csv  #載入專門開csv檔案的套件
import jieba
import jieba.analyse  #載入能萃取出文章中關鍵詞的功能
#jieba.set_dictionary('jieba.txt')   #載入中文繁體字詞庫
jieba.set_dictionary('dict.txt')

pen = []                                    # 第二本
stopkey = open('pen.txt','r').readlines()
for p in stopkey:
    pen.append(p.strip())
    
card = []                                    # 第二本
stopkey = open('card.txt','r').readlines()
for c in stopkey:
    card.append(c.strip())
    

# floder = []                                    # 第二本
# stopkey = open('floder.txt','r').readlines()
# for f in stopkey:
#     floder.append(f.strip())

# paper = []                                    # 第二本
# stopkey = open('paper.txt','r').readlines()
# for p in stopkey:
#     paper.append(p.strip())

# stick = []                                    # 第二本
# stopkey = open('stick.txt','r').readlines()
# for s in stopkey:
#     paper.append(s.strip()

stop = []
stopkey = open('stop.txt','r').readlines()
for s in stopkey:
    stop.append(s.strip())
print(floder)
# Out:
# ['資料本', '資料夾']

# %%
content = []   #裝最後分詞完的結果
contents = open('POS5007_DEMO.csv', 'r').readlines()    #開啟檔案
for row in csv.DictReader(contents):    #csv.DictReader函式可依欄位名開啟特定欄位
    words = jieba.cut(row['PLU_Name'].replace(' ',''), cut_all=False)    #只讓'PLU_Name'此欄位下的內容做斷詞
    temp = []    #每個詞斷出的結果
    for word in words:
#         if '卡' in word :        # 補字
#             temp.append('卡片')

#         if word in pen :          # 第二本
#             temp.append(word)
#         if 'card' in word :         # 第二本
#             temp.append('卡')
#       if word in floder :       # 第二本
#            temp.append(word)
#       if word in paper :         # 第二本
#            temp.append(word)

#       if word in stick :         # 第二本
#            temp.append(word)

        if word not in stop:
            temp.append(word)

    content.append(temp)
content
# Out:
# Building prefix dict from /home/wei/github/firstcode/Team/Jieba/dict.txt ...
# Dumping model to file cache /tmp/jieba.u5fd05ebb5dff1053111aef381e507c7c.cache
# Loading model cost 0.845 seconds.
# Prefix dict has been built succesfully.
# [['喵喵', '18', '元', '卡片', '希'],
#  ['北極熊', '生日卡', '氣'],
#  ['心意', '感謝卡'],
#  ['萬用', '禮卡', '虹象', 'FK'],
#  ['CKSBP', '238', '彩格', '彩格'],
#  ['CKSBP', '238', '彩格', '彩格'],
#  ['UM151', '藍.38', '藍.38'],
#  ['CKSBP', '238', '彩格', '彩格'],
#  ['陳又凌', '小卡', '慶祝'],
#  ['喵喵', '18', '元', '卡片', '最'],
#  ['本木', '生活', '32K', '空白'],
#  ['S203', '壓克力', '水彩', '顏'],
#  ['百樂', '鋼珠筆', 'C310'],
#  ['特', 'B5', '26', '孔', '活頁紙'],
#  ['隨意', '盒', 'OF', 'A03'],
#  ['開放式', '圓孔', '雜誌', '箱'],
#  ['2015', '月曆', '貼紙'],
#  ['3M812', '可再貼', '補充'],
#  ['3M812', '可再貼', '補充'],
#  ['A4', '銀點紙', '6', '色'],
#  ['A4', '義', '星幻紙'],
#  ['大', '4K', '氣泡', '紅框', '資料'],
#  ['黑皮', '立體卡', '貓咪'],
#  ['足勇', '81009', '美工刀'],
#  ['害羞', '小熊', '筆袋', '5706'],
#  ['時尚', '輕便袋', '100K'],
#  ['O', 'CAT', '貓耳', '燒餅包'],
#  ['O', 'CAT', '貓耳', '燒餅包'],
#  ['北極熊', '雙面', '膠帶', '12'],
#  ['北極熊', '雙面', '膠帶', '6m'],
#  ['香水', '紅包袋', '50', '入'],
#  ['資料本', '40', '頁', '入紙'],
#  ['13K', '防護', '收納網袋'],
#  ['9K', '牛皮', '信封', '100', '入'],
#  ['5K', '牛皮', '信封', '100', '入'],
#  ['新德牌', 'U310', '文件套'],
#  ['一般', '型免', '機器', '護貝'],
#  ['自強', '粉筆', '綠', '藍'],
#  ['2015', '事務', '靚彩', '手冊'],
#  ['百點', 'ZE80', '橡皮擦', '綠'],
#  ['3M8', '色', '螢光', '標籤', '58'],
#  ['UM151', '酒紅.38', '酒紅.38'],
#  ['新', '雲龍', '色紙', '100', '入'],
#  ['A4190P', '道林紙', '20'],
#  ['A4', '雪白', '特厚紙', '白'],
#  ['粉彩紙', '混合', '包', 'A4'],
#  ['美術紙', 'A4', '總'],
#  ['犀鳥', '單色', '毛線'],
#  ['美術紙', 'A4', '總'],
#  ['時尚', '輕便袋', '50K'],
#  ['3M', '隱形', '膠帶', '810', '3'],
#  ['點心犬', '面紙', '1075'],
#  ['可愛', '女孩', '面紙', '3232'],
#  ['加厚', '直魔扣', '公文袋'],
#  ['波拉', '貝爾', '隨意貼', '3'],
#  ['快乾膠'],
#  ['動物', '樂園', '32K', '隨手'],
#  ['2015o', 'cat', '年度', '手'],
#  ['雄獅', '200', '奇異筆', '黑'],
#  ['OB', '1007', '原子筆'],
#  ['poca32', '入', '信紙'],
#  ['新', '25K', '定頁筆記', '熊'],
#  ['Ohayo25K', '橫線'],
#  ['Ohayo25K', '橫線'],
#  ['WL', '1008', '華麗', '標籤'],
#  ['特', '29', '元', '50K', '膠面', '便'],
#  ['3M', '狠', '黏', '紙磚', '便條紙'],
#  ['IP', '1002', '0.5', '自動'],
#  ['上昇', '彩虹筆', '單'],
#  ['愛', '簡單', 'A4400', '字稿'],
#  ['雄獅', 'FM', '35', '螢光筆'],
#  ['雄獅', 'GS', '104', '口紅膠'],
#  ['優點', '可', '擦拭', '螢光筆'],
#  ['百樂', '10R', '原子筆', '藍'],
#  ['20X2mm', '超強', '磁鐵'],
#  ['手繪', '塗鴉', '兔子', '生'],
#  ['三菱', '157S', '溜溜筆'],
#  ['三菱', '157S', '溜溜筆'],
#  ['E310L', '型', '文件夾', '白'],
#  ['霧面', '透明', '封箱', '膠帶'],
#  ['富士', '雙倍', '超黏', '多用'],
#  ['A4', '電腦', '標籤', '紙', '2X5'],
#  ['A4', '電腦', '標籤', '紙', '2X4'],
#  ['實用型', 'EZ', '資料袋', '1'],
#  ['超厚型', 'EZ', '資料袋', '1'],
#  ['台灣', '遊藝貼'],
#  ['連續', '漫畫', '貼紙', '恐'],
#  ['雄獅', '金屬色', '奇異筆'],
#  ['雄獅', '金屬色', '奇異筆'],
#  ['雄獅', '金屬色', '奇異筆'],
#  ['雄獅', '金屬色', '奇異筆'],
#  ['雄獅', '金屬色', '奇異筆'],
#  ['北極熊', '10', '元', '膠帶', '連'],
#  ['資料本', '20', '頁', '入紙'],
#  ['資料本', '40', '頁', '入紙'],
#  ['NC25K', '膠圈筆記', '黑'],
#  ['冰雪', '奇緣', '16K', '固頁'],
#  ['奶油', '獅', '169', '好朋友'],
#  ['奶油', '獅', '167', '好朋友'],
#  ['雄獅', '1101HB', '昆蟲'],
#  ['雄獅', '12', '色', '特大', '粉蠟'],
#  ['百點', '彩色鉛筆', '12C'],
#  ['32K', '定頁筆記本', '方'],
#  ['32K', '定頁筆記本', '空'],
#  ['可愛', '卡通', '裝飾', '膠帶'],
#  ['冰棒', '工藝', '（', '14cm'],
#  ['minidoll64k', '筆記'],
#  ['小熊', '64K', '三式筆記'],
#  ['SDICT', '206', '修正帶'],
#  ['SDICT', '204', '修正帶'],
#  ['呵', '比獅', '折尺'],
#  ['開學', '洞洞尺'],
#  ['橡皮圈', '30', '1', '2', '磅入'],
#  ['DOUBLEA', '影印紙', 'A4'],
#  ['WH606R', '滾輪', '替換帶'],
#  ['布', '膠帶', '48mm', '15Y'],
#  ['Q310', '文件套', '附桿'],
#  ['樺木', '衣夾', '大', '0534'],
#  ['壓克力', '展示框', '8', '5'],
#  ['壓克力', '展示框', '7', '4'],
#  ['新年快樂貼', '20', '元'],
#  ['歡樂新年貼', '20', '元'],
#  ['norino', '豆豆', '彩貼', '6'],
#  ['三菱', '102', '螢光筆', '粉'],
#  ['三菱', '102', '螢光筆', '黃'],
#  ['迪士尼', '授權', '紅包袋'],
#  ['冰雪', '奇緣', '授權', '紅包'],
#  ['OB10080', '4', '原子筆'],
#  ['手牌', '烤漆', '書架', '1724'],
#  ['三菱', '代用', '針筆', '黑'],
#  ['WL', '2029Y', '華麗', '彩色']]
